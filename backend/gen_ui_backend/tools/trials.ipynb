# %%
import requests

BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0 Safari/537.36",
    "Accept": "application/json"
}

def fetch_categories():
    url = f"{BASE_URL}categories/"
    resp = requests.get(url, headers=HEADERS, timeout=10)
    if resp.status_code == 200:
        return resp.json().get("results", [])
    else:
        print(f"Error {resp.status_code} al obtener categorías")
        return []

def print_category_names(categories, level=0):
    """Imprime recursivamente los nombres de categorías y subcategorías"""
    for cat in categories:
        print("  " * level + f"- {cat.get('name', 'sin nombre')}")
        if "categories" in cat and cat["categories"]:
            print_category_names(cat["categories"], level + 1)

if __name__ == "__main__":
    categories = fetch_categories()
    if categories:
        print("Categorías de Mercadona:")
        print_category_names(categories)
    else:
        print("No se obtuvieron categorías.")
# Out:
# Categorías de Mercadona:
# - Aceite, especias y salsas
#   - Aceite, vinagre y sal
#   - Especias
#   - Mayonesa, ketchup y mostaza
#   - Otras salsas
# - Agua y refrescos
#   - Agua
#   - Isotónico y energético
#   - Refresco de cola
#   - Refresco de naranja y de limón
#   - Tónica y bitter
#   - Refresco de té y sin gas
# - Aperitivos
#   - Aceitunas y encurtidos
#   - Frutos secos y fruta desecada
#   - Patatas fritas y snacks
# - Arroz, legumbres y pasta
#   - Arroz
#   - Legumbres
#   - Pasta y fideos
# - Azúcar, caramelos y chocolate
#   - Azúcar y edulcorante
#   - Chicles y caramelos
#   - Chocolate
#   - Golosinas
#   - Mermelada y miel
#   - Turrones
# - Bebé
#   - Alimentación infantil
#   - Biberón y chupete
#   - Higiene y cuidado
#   - Toallitas y pañales
# - Bodega
#   - Cerveza
#   - Cerveza sin alcohol
#   - Licores
#   - Sidra y cava
#   - Tinto de verano y sangría
#   - Vino blanco
#   - Vino lambrusco y espumoso
#   - Vino rosado
#   - Vino tinto
# - Cacao, café e infusiones
#   - Cacao soluble y chocolate a la taza
#   - Café cápsula y monodosis
#   - Café molido y en grano
#   - Café soluble y otras bebidas
#   - Té e infusiones
# - Carne
#   - Arreglos
#   - Aves y pollo
#   - Carne congelada
#   - Cerdo
#   - Conejo y cordero
#   - Embutido
#   - Hamburguesas y picadas
#   - Vacuno
#   - Empanados y elaborados
# - Cereales y galletas
#   - Cereales
#   - Galletas
#   - Tortitas
# - Charcutería y quesos
#   - Aves y jamón cocido
#   - Bacón y salchichas
#   - Chopped y mortadela
#   - Embutido curado
#   - Jamón serrano
#   - Paté y sobrasada
#   - Queso curado, semicurado y tierno
#   - Queso lonchas, rallado y en porciones
#   - Queso untable y fresco
# - Congelados
#   - Arroz y pasta
#   - Carne
#   - Helados
#   - Hielo
#   - Marisco
#   - Pescado
#   - Pizzas
#   - Rebozados
#   - Tartas y churros
#   - Verdura
# - Conservas, caldos y cremas
#   - Atún y otras conservas de pescado
#   - Berberechos y mejillones
#   - Conservas de verdura y frutas
#   - Gazpacho y cremas
#   - Sopa y caldo
#   - Tomate
# - Cuidado del cabello
#   - Acondicionador y mascarilla
#   - Champú
#   - Coloración cabello
#   - Fijación cabello
# - Cuidado facial y corporal
#   - Afeitado y cuidado para hombre
#   - Cuidado corporal
#   - Cuidado e higiene facial
#   - Depilación
#   - Desodorante
#   - Gel y jabón de manos
#   - Higiene bucal
#   - Higiene íntima
#   - Manicura y pedicura
#   - Perfume y colonia
#   - Protector solar y aftersun
# - Fitoterapia y parafarmacia
#   - Fitoterapia
#   - Parafarmacia
# - Fruta y verdura
#   - Fruta
#   - Lechuga y ensalada preparada
#   - Verdura
# - Huevos, leche y mantequilla
#   - Huevos
#   - Leche y bebidas vegetales
#   - Mantequilla y margarina
# - Limpieza y hogar
#   - Detergente y suavizante ropa
#   - Estropajo, bayeta y guantes
#   - Insecticida y ambientador
#   - Lejía y líquidos fuertes
#   - Limpiacristales
#   - Limpiahogar y friegasuelos
#   - Limpieza baño y WC
#   - Limpieza cocina
#   - Limpieza muebles y multiusos
#   - Limpieza vajilla
#   - Menaje y conservación de alimentos
#   - Papel higiénico y celulosa
#   - Pilas y bolsas de basura
#   - Utensilios de limpieza y calzado
# - Maquillaje
#   - Bases de maquillaje y corrector
#   - Colorete y polvos
#   - Labios
#   - Ojos
#   - Pinceles y brochas
# - Marisco y pescado
#   - Marisco
#   - Pescado congelado
#   - Pescado fresco
#   - Salazones y ahumados
# - Mascotas
#   - Gato
#   - Perro
#   - Otros
# - Panadería y pastelería
#   - Bollería de horno
#   - Bollería envasada
#   - Harina y preparado repostería
#   - Pan de horno
#   - Pan de molde y otras especialidades
#   - Pan tostado y rallado
#   - Picos, rosquilletas y picatostes
#   - Tartas y pasteles
#   - Velas y decoración
# - Pizzas y platos preparados
#   - Listo para Comer
#   - Pizzas
#   - Platos preparados calientes
#   - Platos preparados fríos
# - Postres y yogures
#   - Bífidus
#   - Flan y natillas
#   - Gelatina y otros postres
#   - Postres de soja
#   - Yogures desnatados
#   - Yogures griegos
#   - Yogures líquidos
#   - Yogures naturales y sabores
#   - Yogures y postres infantiles
# - Zumos
#   - Fruta variada
#   - Melocotón y piña
#   - Naranja
#   - Tomate y otros sabores

# %%
import requests
import csv

BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0 Safari/537.36",
    "Accept": "application/json"
}

def fetch_categories():
    url = f"{BASE_URL}categories/"
    resp = requests.get(url, headers=HEADERS, timeout=10)
    if resp.status_code == 200:
        return resp.json().get("results", [])
    else:
        print(f"Error {resp.status_code} al obtener categorías")
        return []

def fetch_products(category_id):
    """Obtiene todos los productos de una categoría"""
    url = f"{BASE_URL}categories/{category_id}/products/"
    resp = requests.get(url, headers=HEADERS, timeout=10)
    if resp.status_code == 200:
        return resp.json().get("results", [])
    else:
        print(f"Error {resp.status_code} al obtener productos de categoría {category_id}")
        return []

def process_category(cat, csv_writer):
    """Procesa la categoría, sus subcategorías y guarda productos en CSV"""
    # Guardar productos de esta categoría
    products = fetch_products(cat["id"])
    for prod in products:
        csv_writer.writerow({
            "category_id": cat["id"],
            "category_name": cat["name"],
            "product_id": prod.get("id", ""),
            "product_name": prod.get("name", ""),
            "price": prod.get("price", "")
        })

    # Recursivamente procesar subcategorías
    if "categories" in cat and cat["categories"]:
        for subcat in cat["categories"]:
            process_category(subcat, csv_writer)

if __name__ == "__main__":
    categories = fetch_categories()
    if categories:
        with open("productos_mercadona.csv", "w", newline="", encoding="utf-8") as csvfile:
            fieldnames = ["category_id", "category_name", "product_id", "product_name", "price"]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            
            for cat in categories:
                process_category(cat, writer)
        print("CSV generado correctamente: productos_mercadona.csv")
    else:
        print("No se obtuvieron categorías.")
# Out:
# Error 404 al obtener productos de categoría 12
# Error 404 al obtener productos de categoría 112
# Error 404 al obtener productos de categoría 115
# Error 404 al obtener productos de categoría 116
# Error 404 al obtener productos de categoría 117
# Error 404 al obtener productos de categoría 18
# Error 404 al obtener productos de categoría 156
# Error 404 al obtener productos de categoría 163
# Error 404 al obtener productos de categoría 158
# Error 404 al obtener productos de categoría 159
# Error 404 al obtener productos de categoría 161
# Error 404 al obtener productos de categoría 162
# Error 404 al obtener productos de categoría 15
# Error 404 al obtener productos de categoría 135
# Error 404 al obtener productos de categoría 133
# Error 404 al obtener productos de categoría 132
# Error 404 al obtener productos de categoría 13
# Error 404 al obtener productos de categoría 118
# Error 404 al obtener productos de categoría 121
# Error 404 al obtener productos de categoría 120
# Error 404 al obtener productos de categoría 9
# Error 404 al obtener productos de categoría 89
# Error 404 al obtener productos de categoría 95
# Error 404 al obtener productos de categoría 92
# Error 404 al obtener productos de categoría 97
# Error 404 al obtener productos de categoría 90
# Error 404 al obtener productos de categoría 833
# Error 404 al obtener productos de categoría 24
# Error 404 al obtener productos de categoría 216
# Error 404 al obtener productos de categoría 219
# Error 404 al obtener productos de categoría 218
# Error 404 al obtener productos de categoría 217
# Error 404 al obtener productos de categoría 19
# Error 404 al obtener productos de categoría 164
# Error 404 al obtener productos de categoría 166
# Error 404 al obtener productos de categoría 181
# Error 404 al obtener productos de categoría 174
# Error 404 al obtener productos de categoría 168
# Error 404 al obtener productos de categoría 170
# Error 404 al obtener productos de categoría 173
# Error 404 al obtener productos de categoría 171
# Error 404 al obtener productos de categoría 169
# Error 404 al obtener productos de categoría 8
# Error 404 al obtener productos de categoría 86
# Error 404 al obtener productos de categoría 81
# Error 404 al obtener productos de categoría 83
# Error 404 al obtener productos de categoría 84
# Error 404 al obtener productos de categoría 88
# Error 404 al obtener productos de categoría 3
# Error 404 al obtener productos de categoría 46
# Error 404 al obtener productos de categoría 38
# Error 404 al obtener productos de categoría 47
# Error 404 al obtener productos de categoría 37
# Error 404 al obtener productos de categoría 42
# Error 404 al obtener productos de categoría 43
# Error 404 al obtener productos de categoría 44
# Error 404 al obtener productos de categoría 40
# Error 404 al obtener productos de categoría 45
# Error 404 al obtener productos de categoría 7
# Error 404 al obtener productos de categoría 78
# Error 404 al obtener productos de categoría 80
# Error 404 al obtener productos de categoría 79
# Error 404 al obtener productos de categoría 4
# Error 404 al obtener productos de categoría 48
# Error 404 al obtener productos de categoría 52
# Error 404 al obtener productos de categoría 49
# Error 404 al obtener productos de categoría 51
# Error 404 al obtener productos de categoría 50
# Error 404 al obtener productos de categoría 58
# Error 404 al obtener productos de categoría 54
# Error 404 al obtener productos de categoría 56
# Error 404 al obtener productos de categoría 53
# Error 404 al obtener productos de categoría 17
# Error 404 al obtener productos de categoría 147
# Error 404 al obtener productos de categoría 148
# Error 404 al obtener productos de categoría 154
# Error 404 al obtener productos de categoría 155
# Error 404 al obtener productos de categoría 150
# Error 404 al obtener productos de categoría 149
# Error 404 al obtener productos de categoría 151
# Error 404 al obtener productos de categoría 884
# Error 404 al obtener productos de categoría 152
# Error 404 al obtener productos de categoría 145
# Error 404 al obtener productos de categoría 14
# Error 404 al obtener productos de categoría 122
# Error 404 al obtener productos de categoría 123
# Error 404 al obtener productos de categoría 127
# Error 404 al obtener productos de categoría 130
# Error 404 al obtener productos de categoría 129
# Error 404 al obtener productos de categoría 126
# Error 404 al obtener productos de categoría 21
# Error 404 al obtener productos de categoría 201
# Error 404 al obtener productos de categoría 199
# Error 404 al obtener productos de categoría 203
# Error 404 al obtener productos de categoría 202
# Error 404 al obtener productos de categoría 20
# Error 404 al obtener productos de categoría 192
# Error 404 al obtener productos de categoría 189
# Error 404 al obtener productos de categoría 185
# Error 404 al obtener productos de categoría 191
# Error 404 al obtener productos de categoría 188
# Error 404 al obtener productos de categoría 187
# Error 404 al obtener productos de categoría 186
# Error 404 al obtener productos de categoría 190
# Error 404 al obtener productos de categoría 194
# Error 404 al obtener productos de categoría 196
# Error 404 al obtener productos de categoría 198
# Error 404 al obtener productos de categoría 23
# Error 404 al obtener productos de categoría 213
# Error 404 al obtener productos de categoría 214
# Error 404 al obtener productos de categoría 1
# Error 404 al obtener productos de categoría 27
# Error 404 al obtener productos de categoría 28
# Error 404 al obtener productos de categoría 29
# Error 404 al obtener productos de categoría 6
# Error 404 al obtener productos de categoría 77
# Error 404 al obtener productos de categoría 72
# Error 404 al obtener productos de categoría 75
# Error 404 al obtener productos de categoría 26
# Error 404 al obtener productos de categoría 226
# Error 404 al obtener productos de categoría 237
# Error 404 al obtener productos de categoría 241
# Error 404 al obtener productos de categoría 234
# Error 404 al obtener productos de categoría 235
# Error 404 al obtener productos de categoría 233
# Error 404 al obtener productos de categoría 231
# Error 404 al obtener productos de categoría 230
# Error 404 al obtener productos de categoría 232
# Error 404 al obtener productos de categoría 229
# Error 404 al obtener productos de categoría 243
# Error 404 al obtener productos de categoría 238
# Error 404 al obtener productos de categoría 239
# Error 404 al obtener productos de categoría 244
# Error 404 al obtener productos de categoría 22
# Error 404 al obtener productos de categoría 206
# Error 404 al obtener productos de categoría 207
# Error 404 al obtener productos de categoría 208
# Error 404 al obtener productos de categoría 210
# Error 404 al obtener productos de categoría 212
# Error 404 al obtener productos de categoría 2
# Error 404 al obtener productos de categoría 32
# Error 404 al obtener productos de categoría 34
# Error 404 al obtener productos de categoría 31
# Error 404 al obtener productos de categoría 36
# Error 404 al obtener productos de categoría 25
# Error 404 al obtener productos de categoría 222
# Error 404 al obtener productos de categoría 221
# Error 404 al obtener productos de categoría 225
# Error 404 al obtener productos de categoría 5
# Error 404 al obtener productos de categoría 65
# Error 404 al obtener productos de categoría 66
# Error 404 al obtener productos de categoría 69
# Error 404 al obtener productos de categoría 59
# Error 404 al obtener productos de categoría 60
# Error 404 al obtener productos de categoría 62
# Error 404 al obtener productos de categoría 64
# Error 404 al obtener productos de categoría 68
# Error 404 al obtener productos de categoría 71
# Error 404 al obtener productos de categoría 16
# Error 404 al obtener productos de categoría 897
# Error 404 al obtener productos de categoría 138
# Error 404 al obtener productos de categoría 140
# Error 404 al obtener productos de categoría 142
# Error 404 al obtener productos de categoría 11
# Error 404 al obtener productos de categoría 105
# Error 404 al obtener productos de categoría 110
# Error 404 al obtener productos de categoría 111
# Error 404 al obtener productos de categoría 106
# Error 404 al obtener productos de categoría 103
# Error 404 al obtener productos de categoría 109
# Error 404 al obtener productos de categoría 108
# Error 404 al obtener productos de categoría 104
# Error 404 al obtener productos de categoría 107
# Error 404 al obtener productos de categoría 10
# Error 404 al obtener productos de categoría 99
# Error 404 al obtener productos de categoría 100
# Error 404 al obtener productos de categoría 143
# Error 404 al obtener productos de categoría 98
# CSV generado correctamente: productos_mercadona.csv

# %%
import requests
import csv
import time

# --- Constantes y Configuración ---
BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0.0.0 Safari/537.36",
    "Accept": "application/json"
}
CSV_FILE = "productos_mercadona.csv"
PRODUCT_IDS_SEEN = set()  # Para evitar guardar el mismo producto varias veces
CATEGORY_PATH = []  # Para rastrear la ruta completa de la categoría

# --- Funciones de Utilidad de API ---

def fetch_data(url):
    """Realiza una petición GET a la URL y maneja errores."""
    try:
        # Añadimos un pequeño retraso (delay) entre peticiones para ser corteses con el servidor.
        time.sleep(0.5)
        resp = requests.get(url, headers=HEADERS, timeout=10)
        resp.raise_for_status() # Lanza una excepción para códigos de estado de error (4xx o 5xx)
        return resp.json()
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener datos de {url}: {e}")
        return None

def fetch_categories():
    """Obtiene la lista de categorías principales."""
    url = f"{BASE_URL}categories/"
    data = fetch_data(url)
    return data.get("results", []) if data else []

def fetch_category_products(category_id):
    """Obtiene los detalles y productos para un ID de categoría específico."""
    url = f"{BASE_URL}categories/{category_id}/"
    data = fetch_data(url)
    return data.get("products", []) if data else []

# --- Función de Procesamiento y CSV ---

def write_product_to_csv(writer, product, category_path_str):
    """Extrae los campos relevantes del producto y los escribe en el archivo CSV."""
    
    # Intenta obtener el precio de la estructura 'price_instructions'
    price_info = product.get('price_instructions', {})
    price = price_info.get('unit_price')
    unit_price = price_info.get('bulk_price')
    reference_price = price_info.get('reference_price')
    reference_format = price_info.get('reference_format')

    product_data = {
        "id": product.get("id"),
        "nombre": product.get("display_name"),
        "subtitulo": product.get("packaging"),
        "precio_unidad": price,
        "precio_unidad_por": unit_price,
        "precio_referencia": f"{reference_price} {reference_format}".strip(),
        "ruta_categoria": category_path_str
    }
    
    writer.writerow(product_data)


def traverse_categories_and_save(categories, writer, category_path):
    """Recorre recursivamente las categorías, extrae los productos y los guarda."""
    for cat in categories:
        cat_id = cat.get('id')
        cat_name = cat.get('name')
        
        if not cat_id or not cat_name:
            continue

        # 1. Actualiza la ruta de la categoría actual
        current_category_path = category_path + [cat_name]
        category_path_str = " > ".join(current_category_path)
        
        print(f"-> Procesando Categoría: {category_path_str} (ID: {cat_id})")

        # 2. Obtiene los productos de la categoría/subcategoría
        products = fetch_category_products(cat_id)
        
        # 3. Itera sobre los productos y los guarda
        for product in products:
            product_id = product.get('id')
            if product_id and product_id not in PRODUCT_IDS_SEEN:
                write_product_to_csv(writer, product, category_path_str)
                PRODUCT_IDS_SEEN.add(product_id)

        # 4. Llama recursivamente a las subcategorías
        if "categories" in cat and cat["categories"]:
            traverse_categories_and_save(cat["categories"], writer, current_category_path)


# --- Ejecución Principal ---

if __name__ == "__main__":
    print(f"Iniciando la extracción de productos de Mercadona y guardando en {CSV_FILE}...")
    
    # Definición de las cabeceras (headers) del CSV
    fieldnames = [
        "id", 
        "nombre", 
        "subtitulo", 
        "precio_unidad", 
        "precio_unidad_por", 
        "precio_referencia",
        "ruta_categoria"
    ]
    
    try:
        # Abrimos el archivo CSV y lo inicializamos con las cabeceras
        with open(CSV_FILE, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter=';')
            writer.writeheader()

            # 1. Obtiene las categorías principales
            top_level_categories = fetch_categories()
            
            if top_level_categories:
                # 2. Inicia el recorrido recursivo
                traverse_categories_and_save(top_level_categories, writer, [])
                print(f"\n✅ Proceso completado. Total de productos únicos guardados: {len(PRODUCT_IDS_SEEN)}")
            else:
                print("❌ No se pudieron obtener categorías para comenzar.")
                
    except Exception as e:
        print(f"\n❌ Ocurrió un error inesperado durante la escritura del archivo: {e}")
# Out:
# Iniciando la extracción de productos de Mercadona y guardando en productos_mercadona.csv...
# -> Procesando Categoría: Aceite, especias y salsas (ID: 12)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/12/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/12/
# -> Procesando Categoría: Aceite, especias y salsas > Aceite, vinagre y sal (ID: 112)
# -> Procesando Categoría: Aceite, especias y salsas > Especias (ID: 115)
# -> Procesando Categoría: Aceite, especias y salsas > Mayonesa, ketchup y mostaza (ID: 116)
# -> Procesando Categoría: Aceite, especias y salsas > Otras salsas (ID: 117)
# -> Procesando Categoría: Agua y refrescos (ID: 18)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/18/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/18/
# -> Procesando Categoría: Agua y refrescos > Agua (ID: 156)
# -> Procesando Categoría: Agua y refrescos > Isotónico y energético (ID: 163)
# -> Procesando Categoría: Agua y refrescos > Refresco de cola (ID: 158)
# -> Procesando Categoría: Agua y refrescos > Refresco de naranja y de limón (ID: 159)
# -> Procesando Categoría: Agua y refrescos > Tónica y bitter (ID: 161)
# -> Procesando Categoría: Agua y refrescos > Refresco de té y sin gas (ID: 162)
# -> Procesando Categoría: Aperitivos (ID: 15)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/15/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/15/
# -> Procesando Categoría: Aperitivos > Aceitunas y encurtidos (ID: 135)
# -> Procesando Categoría: Aperitivos > Frutos secos y fruta desecada (ID: 133)
# -> Procesando Categoría: Aperitivos > Patatas fritas y snacks (ID: 132)
# -> Procesando Categoría: Arroz, legumbres y pasta (ID: 13)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/13/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/13/
# -> Procesando Categoría: Arroz, legumbres y pasta > Arroz (ID: 118)
# -> Procesando Categoría: Arroz, legumbres y pasta > Legumbres (ID: 121)
# -> Procesando Categoría: Arroz, legumbres y pasta > Pasta y fideos (ID: 120)
# -> Procesando Categoría: Azúcar, caramelos y chocolate (ID: 9)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/9/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/9/
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Azúcar y edulcorante (ID: 89)
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Chicles y caramelos (ID: 95)
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Chocolate (ID: 92)
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Golosinas (ID: 97)
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Mermelada y miel (ID: 90)
# -> Procesando Categoría: Azúcar, caramelos y chocolate > Turrones (ID: 833)
# -> Procesando Categoría: Bebé (ID: 24)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/24/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/24/
# -> Procesando Categoría: Bebé > Alimentación infantil (ID: 216)
# -> Procesando Categoría: Bebé > Biberón y chupete (ID: 219)
# -> Procesando Categoría: Bebé > Higiene y cuidado (ID: 218)
# -> Procesando Categoría: Bebé > Toallitas y pañales (ID: 217)
# -> Procesando Categoría: Bodega (ID: 19)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/19/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/19/
# -> Procesando Categoría: Bodega > Cerveza (ID: 164)
# -> Procesando Categoría: Bodega > Cerveza sin alcohol (ID: 166)
# -> Procesando Categoría: Bodega > Licores (ID: 181)
# -> Procesando Categoría: Bodega > Sidra y cava (ID: 174)
# -> Procesando Categoría: Bodega > Tinto de verano y sangría (ID: 168)
# -> Procesando Categoría: Bodega > Vino blanco (ID: 170)
# -> Procesando Categoría: Bodega > Vino lambrusco y espumoso (ID: 173)
# -> Procesando Categoría: Bodega > Vino rosado (ID: 171)
# -> Procesando Categoría: Bodega > Vino tinto (ID: 169)
# -> Procesando Categoría: Cacao, café e infusiones (ID: 8)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/8/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/8/
# -> Procesando Categoría: Cacao, café e infusiones > Cacao soluble y chocolate a la taza (ID: 86)
# -> Procesando Categoría: Cacao, café e infusiones > Café cápsula y monodosis (ID: 81)
# -> Procesando Categoría: Cacao, café e infusiones > Café molido y en grano (ID: 83)
# -> Procesando Categoría: Cacao, café e infusiones > Café soluble y otras bebidas (ID: 84)
# -> Procesando Categoría: Cacao, café e infusiones > Té e infusiones (ID: 88)
# -> Procesando Categoría: Carne (ID: 3)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/3/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/3/
# -> Procesando Categoría: Carne > Arreglos (ID: 46)
# -> Procesando Categoría: Carne > Aves y pollo (ID: 38)
# -> Procesando Categoría: Carne > Carne congelada (ID: 47)
# -> Procesando Categoría: Carne > Cerdo (ID: 37)
# -> Procesando Categoría: Carne > Conejo y cordero (ID: 42)
# -> Procesando Categoría: Carne > Embutido (ID: 43)
# -> Procesando Categoría: Carne > Hamburguesas y picadas (ID: 44)
# -> Procesando Categoría: Carne > Vacuno (ID: 40)
# -> Procesando Categoría: Carne > Empanados y elaborados (ID: 45)
# -> Procesando Categoría: Cereales y galletas (ID: 7)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/7/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/7/
# -> Procesando Categoría: Cereales y galletas > Cereales (ID: 78)
# -> Procesando Categoría: Cereales y galletas > Galletas (ID: 80)
# -> Procesando Categoría: Cereales y galletas > Tortitas (ID: 79)
# -> Procesando Categoría: Charcutería y quesos (ID: 4)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/4/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/4/
# -> Procesando Categoría: Charcutería y quesos > Aves y jamón cocido (ID: 48)
# -> Procesando Categoría: Charcutería y quesos > Bacón y salchichas (ID: 52)
# -> Procesando Categoría: Charcutería y quesos > Chopped y mortadela (ID: 49)
# -> Procesando Categoría: Charcutería y quesos > Embutido curado (ID: 51)
# -> Procesando Categoría: Charcutería y quesos > Jamón serrano (ID: 50)
# -> Procesando Categoría: Charcutería y quesos > Paté y sobrasada (ID: 58)
# -> Procesando Categoría: Charcutería y quesos > Queso curado, semicurado y tierno (ID: 54)
# -> Procesando Categoría: Charcutería y quesos > Queso lonchas, rallado y en porciones (ID: 56)
# -> Procesando Categoría: Charcutería y quesos > Queso untable y fresco (ID: 53)
# -> Procesando Categoría: Congelados (ID: 17)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/17/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/17/
# -> Procesando Categoría: Congelados > Arroz y pasta (ID: 147)
# -> Procesando Categoría: Congelados > Carne (ID: 148)
# -> Procesando Categoría: Congelados > Helados (ID: 154)
# -> Procesando Categoría: Congelados > Hielo (ID: 155)
# -> Procesando Categoría: Congelados > Marisco (ID: 150)
# -> Procesando Categoría: Congelados > Pescado (ID: 149)
# -> Procesando Categoría: Congelados > Pizzas (ID: 151)
# -> Procesando Categoría: Congelados > Rebozados (ID: 884)
# -> Procesando Categoría: Congelados > Tartas y churros (ID: 152)
# -> Procesando Categoría: Congelados > Verdura (ID: 145)
# -> Procesando Categoría: Conservas, caldos y cremas (ID: 14)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/14/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/14/
# -> Procesando Categoría: Conservas, caldos y cremas > Atún y otras conservas de pescado (ID: 122)
# -> Procesando Categoría: Conservas, caldos y cremas > Berberechos y mejillones (ID: 123)
# -> Procesando Categoría: Conservas, caldos y cremas > Conservas de verdura y frutas (ID: 127)
# -> Procesando Categoría: Conservas, caldos y cremas > Gazpacho y cremas (ID: 130)
# -> Procesando Categoría: Conservas, caldos y cremas > Sopa y caldo (ID: 129)
# -> Procesando Categoría: Conservas, caldos y cremas > Tomate (ID: 126)
# -> Procesando Categoría: Cuidado del cabello (ID: 21)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/21/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/21/
# -> Procesando Categoría: Cuidado del cabello > Acondicionador y mascarilla (ID: 201)
# -> Procesando Categoría: Cuidado del cabello > Champú (ID: 199)
# -> Procesando Categoría: Cuidado del cabello > Coloración cabello (ID: 203)
# -> Procesando Categoría: Cuidado del cabello > Fijación cabello (ID: 202)
# -> Procesando Categoría: Cuidado facial y corporal (ID: 20)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/20/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/20/
# -> Procesando Categoría: Cuidado facial y corporal > Afeitado y cuidado para hombre (ID: 192)
# -> Procesando Categoría: Cuidado facial y corporal > Cuidado corporal (ID: 189)
# -> Procesando Categoría: Cuidado facial y corporal > Cuidado e higiene facial (ID: 185)
# -> Procesando Categoría: Cuidado facial y corporal > Depilación (ID: 191)
# -> Procesando Categoría: Cuidado facial y corporal > Desodorante (ID: 188)
# -> Procesando Categoría: Cuidado facial y corporal > Gel y jabón de manos (ID: 187)
# -> Procesando Categoría: Cuidado facial y corporal > Higiene bucal (ID: 186)
# -> Procesando Categoría: Cuidado facial y corporal > Higiene íntima (ID: 190)
# -> Procesando Categoría: Cuidado facial y corporal > Manicura y pedicura (ID: 194)
# -> Procesando Categoría: Cuidado facial y corporal > Perfume y colonia (ID: 196)
# -> Procesando Categoría: Cuidado facial y corporal > Protector solar y aftersun (ID: 198)
# -> Procesando Categoría: Fitoterapia y parafarmacia (ID: 23)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/23/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/23/
# -> Procesando Categoría: Fitoterapia y parafarmacia > Fitoterapia (ID: 213)
# -> Procesando Categoría: Fitoterapia y parafarmacia > Parafarmacia (ID: 214)
# -> Procesando Categoría: Fruta y verdura (ID: 1)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/1/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/1/
# -> Procesando Categoría: Fruta y verdura > Fruta (ID: 27)
# -> Procesando Categoría: Fruta y verdura > Lechuga y ensalada preparada (ID: 28)
# -> Procesando Categoría: Fruta y verdura > Verdura (ID: 29)
# -> Procesando Categoría: Huevos, leche y mantequilla (ID: 6)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/6/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/6/
# -> Procesando Categoría: Huevos, leche y mantequilla > Huevos (ID: 77)
# -> Procesando Categoría: Huevos, leche y mantequilla > Leche y bebidas vegetales (ID: 72)
# -> Procesando Categoría: Huevos, leche y mantequilla > Mantequilla y margarina (ID: 75)
# -> Procesando Categoría: Limpieza y hogar (ID: 26)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/26/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/26/
# -> Procesando Categoría: Limpieza y hogar > Detergente y suavizante ropa (ID: 226)
# -> Procesando Categoría: Limpieza y hogar > Estropajo, bayeta y guantes (ID: 237)
# -> Procesando Categoría: Limpieza y hogar > Insecticida y ambientador (ID: 241)
# -> Procesando Categoría: Limpieza y hogar > Lejía y líquidos fuertes (ID: 234)
# -> Procesando Categoría: Limpieza y hogar > Limpiacristales (ID: 235)
# -> Procesando Categoría: Limpieza y hogar > Limpiahogar y friegasuelos (ID: 233)
# -> Procesando Categoría: Limpieza y hogar > Limpieza baño y WC (ID: 231)
# -> Procesando Categoría: Limpieza y hogar > Limpieza cocina (ID: 230)
# -> Procesando Categoría: Limpieza y hogar > Limpieza muebles y multiusos (ID: 232)
# -> Procesando Categoría: Limpieza y hogar > Limpieza vajilla (ID: 229)
# -> Procesando Categoría: Limpieza y hogar > Menaje y conservación de alimentos (ID: 243)
# -> Procesando Categoría: Limpieza y hogar > Papel higiénico y celulosa (ID: 238)
# -> Procesando Categoría: Limpieza y hogar > Pilas y bolsas de basura (ID: 239)
# -> Procesando Categoría: Limpieza y hogar > Utensilios de limpieza y calzado (ID: 244)
# -> Procesando Categoría: Maquillaje (ID: 22)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/22/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/22/
# -> Procesando Categoría: Maquillaje > Bases de maquillaje y corrector (ID: 206)
# -> Procesando Categoría: Maquillaje > Colorete y polvos (ID: 207)
# -> Procesando Categoría: Maquillaje > Labios (ID: 208)
# -> Procesando Categoría: Maquillaje > Ojos (ID: 210)
# -> Procesando Categoría: Maquillaje > Pinceles y brochas (ID: 212)
# -> Procesando Categoría: Marisco y pescado (ID: 2)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/2/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/2/
# -> Procesando Categoría: Marisco y pescado > Marisco (ID: 32)
# -> Procesando Categoría: Marisco y pescado > Pescado congelado (ID: 34)
# -> Procesando Categoría: Marisco y pescado > Pescado fresco (ID: 31)
# -> Procesando Categoría: Marisco y pescado > Salazones y ahumados (ID: 36)
# -> Procesando Categoría: Mascotas (ID: 25)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/25/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/25/
# -> Procesando Categoría: Mascotas > Gato (ID: 222)
# -> Procesando Categoría: Mascotas > Perro (ID: 221)
# -> Procesando Categoría: Mascotas > Otros (ID: 225)
# -> Procesando Categoría: Panadería y pastelería (ID: 5)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/5/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/5/
# -> Procesando Categoría: Panadería y pastelería > Bollería de horno (ID: 65)
# -> Procesando Categoría: Panadería y pastelería > Bollería envasada (ID: 66)
# -> Procesando Categoría: Panadería y pastelería > Harina y preparado repostería (ID: 69)
# -> Procesando Categoría: Panadería y pastelería > Pan de horno (ID: 59)
# -> Procesando Categoría: Panadería y pastelería > Pan de molde y otras especialidades (ID: 60)
# -> Procesando Categoría: Panadería y pastelería > Pan tostado y rallado (ID: 62)
# -> Procesando Categoría: Panadería y pastelería > Picos, rosquilletas y picatostes (ID: 64)
# -> Procesando Categoría: Panadería y pastelería > Tartas y pasteles (ID: 68)
# -> Procesando Categoría: Panadería y pastelería > Velas y decoración (ID: 71)
# -> Procesando Categoría: Pizzas y platos preparados (ID: 16)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/16/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/16/
# -> Procesando Categoría: Pizzas y platos preparados > Listo para Comer (ID: 897)
# -> Procesando Categoría: Pizzas y platos preparados > Pizzas (ID: 138)
# -> Procesando Categoría: Pizzas y platos preparados > Platos preparados calientes (ID: 140)
# -> Procesando Categoría: Pizzas y platos preparados > Platos preparados fríos (ID: 142)
# -> Procesando Categoría: Postres y yogures (ID: 11)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/11/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/11/
# -> Procesando Categoría: Postres y yogures > Bífidus (ID: 105)
# -> Procesando Categoría: Postres y yogures > Flan y natillas (ID: 110)
# -> Procesando Categoría: Postres y yogures > Gelatina y otros postres (ID: 111)
# -> Procesando Categoría: Postres y yogures > Postres de soja (ID: 106)
# -> Procesando Categoría: Postres y yogures > Yogures desnatados (ID: 103)
# -> Procesando Categoría: Postres y yogures > Yogures griegos (ID: 109)
# -> Procesando Categoría: Postres y yogures > Yogures líquidos (ID: 108)
# -> Procesando Categoría: Postres y yogures > Yogures naturales y sabores (ID: 104)
# -> Procesando Categoría: Postres y yogures > Yogures y postres infantiles (ID: 107)
# -> Procesando Categoría: Zumos (ID: 10)
# Error al obtener datos de https://tienda.mercadona.es/api/categories/10/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/10/
# -> Procesando Categoría: Zumos > Fruta variada (ID: 99)
# -> Procesando Categoría: Zumos > Melocotón y piña (ID: 100)
# -> Procesando Categoría: Zumos > Naranja (ID: 143)
# -> Procesando Categoría: Zumos > Tomate y otros sabores (ID: 98)
#
# ✅ Proceso completado. Total de productos únicos guardados: 0

# %%
import requests
import time

# --- Constantes y Configuración ---
BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0.0.0 Safari/537.36",
    "Accept": "application/json"
}
PRODUCT_IDS_SEEN = set()  # Para evitar procesar el mismo producto varias veces

# --- Funciones de Utilidad de API ---

def fetch_data(url):
    """Realiza una petición GET a la URL y maneja errores."""
    try:
        # Pequeño delay entre peticiones.
        time.sleep(0.5)
        resp = requests.get(url, headers=HEADERS, timeout=10)
        resp.raise_for_status() # Lanza una excepción para códigos de estado de error (4xx o 5xx)
        return resp.json()
    except requests.exceptions.RequestException as e:
        # Imprime la URL y el error para facilitar el debugging
        print(f"❌ Error al obtener datos de {url}: {e}")
        return None

def fetch_categories():
    """Obtiene la lista de categorías principales."""
    url = f"{BASE_URL}categories/"
    data = fetch_data(url)
    return data.get("results", []) if data else []

def fetch_category_products(category_id):
    """Obtiene los detalles y productos para un ID de categoría específico."""
    # Este es el endpoint clave: /api/categories/{category_id}/
    url = f"{BASE_URL}categories/{category_id}/"
    data = fetch_data(url)
    # Devolvemos el listado de productos
    return data.get("products", []) if data else []

# --- Función de Impresión de Detalles ---

def print_product_details(product, category_path_str):
    """Extrae los campos relevantes del producto y los imprime en la consola."""
    
    # Intenta obtener el precio de la estructura 'price_instructions'
    price_info = product.get('price_instructions', {})
    price = price_info.get('unit_price')
    reference_price = price_info.get('reference_price')
    reference_format = price_info.get('reference_format')
    
    # Construcción de la línea de output
    output = (
        f"  - ID: {product.get('id')} | "
        f"Nombre: **{product.get('display_name')}** | "
        f"Precio: {price} | "
        f"Precio Ref.: {reference_price} {reference_format} | "
        f"Categoría: {category_path_str}"
    )
    print(output)


def traverse_categories_and_print(categories, category_path):
    """Recorre recursivamente las categorías y subcategorías."""
    for cat in categories:
        cat_id = cat.get('id')
        cat_name = cat.get('name')
        
        if not cat_id or not cat_name:
            continue

        # 1. Define la ruta de la categoría
        current_category_path = category_path + [cat_name]
        category_path_str = " > ".join(current_category_path)
        
        print(f"\n📢 Procesando Categoría: **{category_path_str}** (ID: {cat_id})")

        # 2. Obtiene los productos de la categoría/subcategoría
        products = fetch_category_products(cat_id)
        
        if products:
            print(f"  🛒 Se encontraron {len(products)} productos. Detalles:")
        else:
            print("  ⚠️ No se encontraron productos.")

        # 3. Itera sobre los productos e imprime sus detalles
        for product in products:
            product_id = product.get('id')
            if product_id and product_id not in PRODUCT_IDS_SEEN:
                print_product_details(product, category_path_str)
                PRODUCT_IDS_SEEN.add(product_id)

        # 4. Llama recursivamente a las subcategorías
        if "categories" in cat and cat["categories"]:
            traverse_categories_and_print(cat["categories"], current_category_path)


# --- Ejecución Principal ---

if __name__ == "__main__":
    print("Iniciando la extracción de productos de Mercadona y mostrando en consola...")
    
    # 1. Obtiene las categorías principales
    top_level_categories = fetch_categories()
    
    if top_level_categories:
        # 2. Inicia el recorrido recursivo
        traverse_categories_and_print(top_level_categories, [])
        print(f"\n✅ Proceso de impresión completado. Total de productos únicos procesados: {len(PRODUCT_IDS_SEEN)}")
    else:
        print("❌ No se pudieron obtener categorías principales para comenzar.")
# Out:
# Iniciando la extracción de productos de Mercadona y mostrando en consola...
#
# 📢 Procesando Categoría: **Aceite, especias y salsas** (ID: 12)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/12/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/12/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aceite, especias y salsas > Aceite, vinagre y sal** (ID: 112)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aceite, especias y salsas > Especias** (ID: 115)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aceite, especias y salsas > Mayonesa, ketchup y mostaza** (ID: 116)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aceite, especias y salsas > Otras salsas** (ID: 117)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos** (ID: 18)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/18/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/18/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Agua** (ID: 156)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Isotónico y energético** (ID: 163)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Refresco de cola** (ID: 158)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Refresco de naranja y de limón** (ID: 159)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Tónica y bitter** (ID: 161)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Agua y refrescos > Refresco de té y sin gas** (ID: 162)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aperitivos** (ID: 15)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/15/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/15/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aperitivos > Aceitunas y encurtidos** (ID: 135)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aperitivos > Frutos secos y fruta desecada** (ID: 133)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Aperitivos > Patatas fritas y snacks** (ID: 132)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Arroz, legumbres y pasta** (ID: 13)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/13/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/13/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Arroz, legumbres y pasta > Arroz** (ID: 118)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Arroz, legumbres y pasta > Legumbres** (ID: 121)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Arroz, legumbres y pasta > Pasta y fideos** (ID: 120)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate** (ID: 9)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/9/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/9/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Azúcar y edulcorante** (ID: 89)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Chicles y caramelos** (ID: 95)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Chocolate** (ID: 92)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Golosinas** (ID: 97)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Mermelada y miel** (ID: 90)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Azúcar, caramelos y chocolate > Turrones** (ID: 833)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bebé** (ID: 24)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/24/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/24/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bebé > Alimentación infantil** (ID: 216)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bebé > Biberón y chupete** (ID: 219)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bebé > Higiene y cuidado** (ID: 218)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bebé > Toallitas y pañales** (ID: 217)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega** (ID: 19)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/19/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/19/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Cerveza** (ID: 164)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Cerveza sin alcohol** (ID: 166)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Licores** (ID: 181)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Sidra y cava** (ID: 174)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Tinto de verano y sangría** (ID: 168)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Vino blanco** (ID: 170)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Vino lambrusco y espumoso** (ID: 173)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Vino rosado** (ID: 171)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Bodega > Vino tinto** (ID: 169)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones** (ID: 8)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/8/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/8/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones > Cacao soluble y chocolate a la taza** (ID: 86)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones > Café cápsula y monodosis** (ID: 81)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones > Café molido y en grano** (ID: 83)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones > Café soluble y otras bebidas** (ID: 84)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cacao, café e infusiones > Té e infusiones** (ID: 88)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne** (ID: 3)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/3/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/3/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Arreglos** (ID: 46)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Aves y pollo** (ID: 38)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Carne congelada** (ID: 47)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Cerdo** (ID: 37)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Conejo y cordero** (ID: 42)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Embutido** (ID: 43)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Hamburguesas y picadas** (ID: 44)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Vacuno** (ID: 40)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Carne > Empanados y elaborados** (ID: 45)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cereales y galletas** (ID: 7)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/7/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/7/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cereales y galletas > Cereales** (ID: 78)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cereales y galletas > Galletas** (ID: 80)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cereales y galletas > Tortitas** (ID: 79)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos** (ID: 4)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/4/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/4/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Aves y jamón cocido** (ID: 48)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Bacón y salchichas** (ID: 52)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Chopped y mortadela** (ID: 49)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Embutido curado** (ID: 51)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Jamón serrano** (ID: 50)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Paté y sobrasada** (ID: 58)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Queso curado, semicurado y tierno** (ID: 54)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Queso lonchas, rallado y en porciones** (ID: 56)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Charcutería y quesos > Queso untable y fresco** (ID: 53)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados** (ID: 17)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/17/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/17/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Arroz y pasta** (ID: 147)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Carne** (ID: 148)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Helados** (ID: 154)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Hielo** (ID: 155)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Marisco** (ID: 150)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Pescado** (ID: 149)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Pizzas** (ID: 151)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Rebozados** (ID: 884)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Tartas y churros** (ID: 152)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Congelados > Verdura** (ID: 145)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas** (ID: 14)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/14/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/14/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Atún y otras conservas de pescado** (ID: 122)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Berberechos y mejillones** (ID: 123)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Conservas de verdura y frutas** (ID: 127)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Gazpacho y cremas** (ID: 130)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Sopa y caldo** (ID: 129)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Conservas, caldos y cremas > Tomate** (ID: 126)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado del cabello** (ID: 21)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/21/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/21/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado del cabello > Acondicionador y mascarilla** (ID: 201)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado del cabello > Champú** (ID: 199)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado del cabello > Coloración cabello** (ID: 203)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado del cabello > Fijación cabello** (ID: 202)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal** (ID: 20)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/20/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/20/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Afeitado y cuidado para hombre** (ID: 192)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Cuidado corporal** (ID: 189)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Cuidado e higiene facial** (ID: 185)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Depilación** (ID: 191)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Desodorante** (ID: 188)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Gel y jabón de manos** (ID: 187)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Higiene bucal** (ID: 186)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Higiene íntima** (ID: 190)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Manicura y pedicura** (ID: 194)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Perfume y colonia** (ID: 196)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Cuidado facial y corporal > Protector solar y aftersun** (ID: 198)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fitoterapia y parafarmacia** (ID: 23)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/23/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/23/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fitoterapia y parafarmacia > Fitoterapia** (ID: 213)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fitoterapia y parafarmacia > Parafarmacia** (ID: 214)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fruta y verdura** (ID: 1)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/1/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/1/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fruta y verdura > Fruta** (ID: 27)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fruta y verdura > Lechuga y ensalada preparada** (ID: 28)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Fruta y verdura > Verdura** (ID: 29)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Huevos, leche y mantequilla** (ID: 6)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/6/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/6/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Huevos, leche y mantequilla > Huevos** (ID: 77)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Huevos, leche y mantequilla > Leche y bebidas vegetales** (ID: 72)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Huevos, leche y mantequilla > Mantequilla y margarina** (ID: 75)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar** (ID: 26)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/26/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/26/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Detergente y suavizante ropa** (ID: 226)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Estropajo, bayeta y guantes** (ID: 237)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Insecticida y ambientador** (ID: 241)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Lejía y líquidos fuertes** (ID: 234)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpiacristales** (ID: 235)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpiahogar y friegasuelos** (ID: 233)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpieza baño y WC** (ID: 231)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpieza cocina** (ID: 230)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpieza muebles y multiusos** (ID: 232)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Limpieza vajilla** (ID: 229)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Menaje y conservación de alimentos** (ID: 243)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Papel higiénico y celulosa** (ID: 238)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Pilas y bolsas de basura** (ID: 239)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Limpieza y hogar > Utensilios de limpieza y calzado** (ID: 244)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje** (ID: 22)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/22/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/22/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje > Bases de maquillaje y corrector** (ID: 206)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje > Colorete y polvos** (ID: 207)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje > Labios** (ID: 208)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje > Ojos** (ID: 210)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Maquillaje > Pinceles y brochas** (ID: 212)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Marisco y pescado** (ID: 2)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/2/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/2/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Marisco y pescado > Marisco** (ID: 32)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Marisco y pescado > Pescado congelado** (ID: 34)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Marisco y pescado > Pescado fresco** (ID: 31)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Marisco y pescado > Salazones y ahumados** (ID: 36)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Mascotas** (ID: 25)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/25/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/25/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Mascotas > Gato** (ID: 222)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Mascotas > Perro** (ID: 221)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Mascotas > Otros** (ID: 225)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería** (ID: 5)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/5/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/5/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Bollería de horno** (ID: 65)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Bollería envasada** (ID: 66)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Harina y preparado repostería** (ID: 69)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Pan de horno** (ID: 59)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Pan de molde y otras especialidades** (ID: 60)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Pan tostado y rallado** (ID: 62)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Picos, rosquilletas y picatostes** (ID: 64)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Tartas y pasteles** (ID: 68)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Panadería y pastelería > Velas y decoración** (ID: 71)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Pizzas y platos preparados** (ID: 16)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/16/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/16/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Pizzas y platos preparados > Listo para Comer** (ID: 897)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Pizzas y platos preparados > Pizzas** (ID: 138)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Pizzas y platos preparados > Platos preparados calientes** (ID: 140)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Pizzas y platos preparados > Platos preparados fríos** (ID: 142)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures** (ID: 11)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/11/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/11/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Bífidus** (ID: 105)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Flan y natillas** (ID: 110)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Gelatina y otros postres** (ID: 111)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Postres de soja** (ID: 106)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Yogures desnatados** (ID: 103)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Yogures griegos** (ID: 109)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Yogures líquidos** (ID: 108)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Yogures naturales y sabores** (ID: 104)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Postres y yogures > Yogures y postres infantiles** (ID: 107)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Zumos** (ID: 10)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/10/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/10/
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Zumos > Fruta variada** (ID: 99)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Zumos > Melocotón y piña** (ID: 100)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Zumos > Naranja** (ID: 143)
#   ⚠️ No se encontraron productos.
#
# 📢 Procesando Categoría: **Zumos > Tomate y otros sabores** (ID: 98)
#   ⚠️ No se encontraron productos.
#
# ✅ Proceso de impresión completado. Total de productos únicos procesados: 0

# %%
import requests
import csv
import time

# --- Constantes y Configuración ---
BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0.0.0 Safari/537.36",
    "Accept": "application/json"
}
CSV_FILE = "productos_mercadona.csv"
PRODUCT_IDS_SEEN = set()  # Usamos un set para almacenar IDs de productos únicos
FIELDNAMES = [
    "id", 
    "nombre", 
    "subtitulo", 
    "precio_unidad", 
    "precio_ref_valor", 
    "precio_ref_formato",
    "ruta_categoria"
]

# --- Funciones de Utilidad de API ---

def fetch_data(url):
    """Realiza una petición GET a la URL y maneja errores."""
    try:
        # Pausa de 0.5s para no sobrecargar la API (buena práctica de web scraping)
        time.sleep(0.5) 
        resp = requests.get(url, headers=HEADERS, timeout=10)
        resp.raise_for_status() # Lanza un HTTPError si el estado es 4xx o 5xx
        return resp.json()
    except requests.exceptions.RequestException as e:
        print(f"❌ Error al obtener datos de {url}: {e}")
        return None

def fetch_categories():
    """Obtiene la lista de categorías principales."""
    url = f"{BASE_URL}categories/"
    data = fetch_data(url)
    return data.get("results", []) if data else []

def fetch_category_products(category_id):
    """Obtiene los detalles y productos para un ID de categoría específico."""
    # Este es el endpoint clave: /api/categories/{category_id}/
    url = f"{BASE_URL}categories/{category_id}/"
    data = fetch_data(url)
    return data.get("products", []) if data else []

# --- Función de Procesamiento y CSV ---

def extract_and_save_product(writer, product, category_path_str):
    """Extrae los campos relevantes del producto y los escribe en el archivo CSV."""
    
    # Intenta obtener el precio de la estructura 'price_instructions'
    price_info = product.get('price_instructions', {})
    
    # Preparamos el diccionario con los datos del producto
    product_data = {
        "id": product.get("id", "N/A"),
        "nombre": product.get("display_name", "N/A"),
        "subtitulo": product.get("packaging", "N/A"),
        "precio_unidad": price_info.get('unit_price', "N/A"),
        "precio_ref_valor": price_info.get('reference_price', "N/A"),
        "precio_ref_formato": price_info.get('reference_format', "N/A"),
        "ruta_categoria": category_path_str
    }
    
    # Escribimos la fila en el CSV
    writer.writerow(product_data)


def traverse_categories_and_save(categories, writer, category_path):
    """Recorre recursivamente las categorías, extrae los productos y los guarda."""
    global PRODUCT_IDS_SEEN # Necesario para modificar el set global

    for cat in categories:
        cat_id = cat.get('id')
        cat_name = cat.get('name')
        
        if not cat_id or not cat_name:
            continue

        # 1. Define la ruta de la categoría actual
        current_category_path = category_path + [cat_name]
        category_path_str = " > ".join(current_category_path)
        
        print(f"-> Procesando: {category_path_str} (ID: {cat_id})")

        # 2. Obtiene los productos de la categoría/subcategoría
        products = fetch_category_products(cat_id)
        
        # 3. Itera sobre los productos y los guarda si son únicos
        for product in products:
            product_id = product.get('id')
            if product_id and product_id not in PRODUCT_IDS_SEEN:
                extract_and_save_product(writer, product, category_path_str)
                PRODUCT_IDS_SEEN.add(product_id)
        
        # 4. Llama recursivamente a las subcategorías
        if "categories" in cat and cat["categories"]:
            traverse_categories_and_save(cat["categories"], writer, current_category_path)


# --- Ejecución Principal ---

if __name__ == "__main__":
    print(f"Iniciando la extracción de productos de Mercadona y guardando en {CSV_FILE}...")
    
    try:
        # Abrimos el archivo CSV en modo escritura, especificamos 'utf-8' y sin líneas en blanco
        with open(CSV_FILE, 'w', newline='', encoding='utf-8') as csvfile:
            # Inicializamos el DictWriter con el delimitador ';'
            writer = csv.DictWriter(csvfile, fieldnames=FIELDNAMES, delimiter=';')
            writer.writeheader() # Escribimos la cabecera
            
            # 1. Obtiene las categorías principales
            top_level_categories = fetch_categories()
            
            if top_level_categories:
                # 2. Inicia el recorrido recursivo
                traverse_categories_and_save(top_level_categories, writer, [])
                print(f"\n✅ Proceso completado. Total de productos únicos guardados: {len(PRODUCT_IDS_SEEN)}")
            else:
                print("❌ No se obtuvieron categorías. Verifica la conexión o el BASE_URL.")
                
    except Exception as e:
        print(f"\n❌ Ocurrió un error inesperado durante la ejecución: {e}")
# Out:
# Iniciando la extracción de productos de Mercadona y guardando en productos_mercadona.csv...
# -> Procesando: Aceite, especias y salsas (ID: 12)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/12/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/12/
# -> Procesando: Aceite, especias y salsas > Aceite, vinagre y sal (ID: 112)
# -> Procesando: Aceite, especias y salsas > Especias (ID: 115)
# -> Procesando: Aceite, especias y salsas > Mayonesa, ketchup y mostaza (ID: 116)
# -> Procesando: Aceite, especias y salsas > Otras salsas (ID: 117)
# -> Procesando: Agua y refrescos (ID: 18)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/18/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/18/
# -> Procesando: Agua y refrescos > Agua (ID: 156)
# -> Procesando: Agua y refrescos > Isotónico y energético (ID: 163)
# -> Procesando: Agua y refrescos > Refresco de cola (ID: 158)
# -> Procesando: Agua y refrescos > Refresco de naranja y de limón (ID: 159)
# -> Procesando: Agua y refrescos > Tónica y bitter (ID: 161)
# -> Procesando: Agua y refrescos > Refresco de té y sin gas (ID: 162)
# -> Procesando: Aperitivos (ID: 15)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/15/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/15/
# -> Procesando: Aperitivos > Aceitunas y encurtidos (ID: 135)
# -> Procesando: Aperitivos > Frutos secos y fruta desecada (ID: 133)
# -> Procesando: Aperitivos > Patatas fritas y snacks (ID: 132)
# -> Procesando: Arroz, legumbres y pasta (ID: 13)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/13/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/13/
# -> Procesando: Arroz, legumbres y pasta > Arroz (ID: 118)
# -> Procesando: Arroz, legumbres y pasta > Legumbres (ID: 121)
# -> Procesando: Arroz, legumbres y pasta > Pasta y fideos (ID: 120)
# -> Procesando: Azúcar, caramelos y chocolate (ID: 9)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/9/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/9/
# -> Procesando: Azúcar, caramelos y chocolate > Azúcar y edulcorante (ID: 89)
# -> Procesando: Azúcar, caramelos y chocolate > Chicles y caramelos (ID: 95)
# -> Procesando: Azúcar, caramelos y chocolate > Chocolate (ID: 92)
# -> Procesando: Azúcar, caramelos y chocolate > Golosinas (ID: 97)
# -> Procesando: Azúcar, caramelos y chocolate > Mermelada y miel (ID: 90)
# -> Procesando: Azúcar, caramelos y chocolate > Turrones (ID: 833)
# -> Procesando: Bebé (ID: 24)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/24/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/24/
# -> Procesando: Bebé > Alimentación infantil (ID: 216)
# -> Procesando: Bebé > Biberón y chupete (ID: 219)
# -> Procesando: Bebé > Higiene y cuidado (ID: 218)
# -> Procesando: Bebé > Toallitas y pañales (ID: 217)
# -> Procesando: Bodega (ID: 19)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/19/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/19/
# -> Procesando: Bodega > Cerveza (ID: 164)
# -> Procesando: Bodega > Cerveza sin alcohol (ID: 166)
# -> Procesando: Bodega > Licores (ID: 181)
# -> Procesando: Bodega > Sidra y cava (ID: 174)
# -> Procesando: Bodega > Tinto de verano y sangría (ID: 168)
# -> Procesando: Bodega > Vino blanco (ID: 170)
# -> Procesando: Bodega > Vino lambrusco y espumoso (ID: 173)
# -> Procesando: Bodega > Vino rosado (ID: 171)
# -> Procesando: Bodega > Vino tinto (ID: 169)
# -> Procesando: Cacao, café e infusiones (ID: 8)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/8/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/8/
# -> Procesando: Cacao, café e infusiones > Cacao soluble y chocolate a la taza (ID: 86)
# -> Procesando: Cacao, café e infusiones > Café cápsula y monodosis (ID: 81)
# -> Procesando: Cacao, café e infusiones > Café molido y en grano (ID: 83)
# -> Procesando: Cacao, café e infusiones > Café soluble y otras bebidas (ID: 84)
# -> Procesando: Cacao, café e infusiones > Té e infusiones (ID: 88)
# -> Procesando: Carne (ID: 3)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/3/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/3/
# -> Procesando: Carne > Arreglos (ID: 46)
# -> Procesando: Carne > Aves y pollo (ID: 38)
# -> Procesando: Carne > Carne congelada (ID: 47)
# -> Procesando: Carne > Cerdo (ID: 37)
# -> Procesando: Carne > Conejo y cordero (ID: 42)
# -> Procesando: Carne > Embutido (ID: 43)
# -> Procesando: Carne > Hamburguesas y picadas (ID: 44)
# -> Procesando: Carne > Vacuno (ID: 40)
# -> Procesando: Carne > Empanados y elaborados (ID: 45)
# -> Procesando: Cereales y galletas (ID: 7)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/7/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/7/
# -> Procesando: Cereales y galletas > Cereales (ID: 78)
# -> Procesando: Cereales y galletas > Galletas (ID: 80)
# -> Procesando: Cereales y galletas > Tortitas (ID: 79)
# -> Procesando: Charcutería y quesos (ID: 4)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/4/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/4/
# -> Procesando: Charcutería y quesos > Aves y jamón cocido (ID: 48)
# -> Procesando: Charcutería y quesos > Bacón y salchichas (ID: 52)
# -> Procesando: Charcutería y quesos > Chopped y mortadela (ID: 49)
# -> Procesando: Charcutería y quesos > Embutido curado (ID: 51)
# -> Procesando: Charcutería y quesos > Jamón serrano (ID: 50)
# -> Procesando: Charcutería y quesos > Paté y sobrasada (ID: 58)
# -> Procesando: Charcutería y quesos > Queso curado, semicurado y tierno (ID: 54)
# -> Procesando: Charcutería y quesos > Queso lonchas, rallado y en porciones (ID: 56)
# -> Procesando: Charcutería y quesos > Queso untable y fresco (ID: 53)
# -> Procesando: Congelados (ID: 17)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/17/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/17/
# -> Procesando: Congelados > Arroz y pasta (ID: 147)
# -> Procesando: Congelados > Carne (ID: 148)
# -> Procesando: Congelados > Helados (ID: 154)
# -> Procesando: Congelados > Hielo (ID: 155)
# -> Procesando: Congelados > Marisco (ID: 150)
# -> Procesando: Congelados > Pescado (ID: 149)
# -> Procesando: Congelados > Pizzas (ID: 151)
# -> Procesando: Congelados > Rebozados (ID: 884)
# -> Procesando: Congelados > Tartas y churros (ID: 152)
# -> Procesando: Congelados > Verdura (ID: 145)
# -> Procesando: Conservas, caldos y cremas (ID: 14)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/14/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/14/
# -> Procesando: Conservas, caldos y cremas > Atún y otras conservas de pescado (ID: 122)
# -> Procesando: Conservas, caldos y cremas > Berberechos y mejillones (ID: 123)
# -> Procesando: Conservas, caldos y cremas > Conservas de verdura y frutas (ID: 127)
# -> Procesando: Conservas, caldos y cremas > Gazpacho y cremas (ID: 130)
# -> Procesando: Conservas, caldos y cremas > Sopa y caldo (ID: 129)
# -> Procesando: Conservas, caldos y cremas > Tomate (ID: 126)
# -> Procesando: Cuidado del cabello (ID: 21)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/21/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/21/
# -> Procesando: Cuidado del cabello > Acondicionador y mascarilla (ID: 201)
# -> Procesando: Cuidado del cabello > Champú (ID: 199)
# -> Procesando: Cuidado del cabello > Coloración cabello (ID: 203)
# -> Procesando: Cuidado del cabello > Fijación cabello (ID: 202)
# -> Procesando: Cuidado facial y corporal (ID: 20)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/20/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/20/
# -> Procesando: Cuidado facial y corporal > Afeitado y cuidado para hombre (ID: 192)
# -> Procesando: Cuidado facial y corporal > Cuidado corporal (ID: 189)
# -> Procesando: Cuidado facial y corporal > Cuidado e higiene facial (ID: 185)
# -> Procesando: Cuidado facial y corporal > Depilación (ID: 191)
# -> Procesando: Cuidado facial y corporal > Desodorante (ID: 188)
# -> Procesando: Cuidado facial y corporal > Gel y jabón de manos (ID: 187)
# -> Procesando: Cuidado facial y corporal > Higiene bucal (ID: 186)
# -> Procesando: Cuidado facial y corporal > Higiene íntima (ID: 190)
# -> Procesando: Cuidado facial y corporal > Manicura y pedicura (ID: 194)
# -> Procesando: Cuidado facial y corporal > Perfume y colonia (ID: 196)
# -> Procesando: Cuidado facial y corporal > Protector solar y aftersun (ID: 198)
# -> Procesando: Fitoterapia y parafarmacia (ID: 23)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/23/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/23/
# -> Procesando: Fitoterapia y parafarmacia > Fitoterapia (ID: 213)
# -> Procesando: Fitoterapia y parafarmacia > Parafarmacia (ID: 214)
# -> Procesando: Fruta y verdura (ID: 1)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/1/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/1/
# -> Procesando: Fruta y verdura > Fruta (ID: 27)
# -> Procesando: Fruta y verdura > Lechuga y ensalada preparada (ID: 28)
# -> Procesando: Fruta y verdura > Verdura (ID: 29)
# -> Procesando: Huevos, leche y mantequilla (ID: 6)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/6/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/6/
# -> Procesando: Huevos, leche y mantequilla > Huevos (ID: 77)
# -> Procesando: Huevos, leche y mantequilla > Leche y bebidas vegetales (ID: 72)
# -> Procesando: Huevos, leche y mantequilla > Mantequilla y margarina (ID: 75)
# -> Procesando: Limpieza y hogar (ID: 26)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/26/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/26/
# -> Procesando: Limpieza y hogar > Detergente y suavizante ropa (ID: 226)
# -> Procesando: Limpieza y hogar > Estropajo, bayeta y guantes (ID: 237)
# -> Procesando: Limpieza y hogar > Insecticida y ambientador (ID: 241)
# -> Procesando: Limpieza y hogar > Lejía y líquidos fuertes (ID: 234)
# -> Procesando: Limpieza y hogar > Limpiacristales (ID: 235)
# -> Procesando: Limpieza y hogar > Limpiahogar y friegasuelos (ID: 233)
# -> Procesando: Limpieza y hogar > Limpieza baño y WC (ID: 231)
# -> Procesando: Limpieza y hogar > Limpieza cocina (ID: 230)
# -> Procesando: Limpieza y hogar > Limpieza muebles y multiusos (ID: 232)
# -> Procesando: Limpieza y hogar > Limpieza vajilla (ID: 229)
# -> Procesando: Limpieza y hogar > Menaje y conservación de alimentos (ID: 243)
# -> Procesando: Limpieza y hogar > Papel higiénico y celulosa (ID: 238)
# -> Procesando: Limpieza y hogar > Pilas y bolsas de basura (ID: 239)
# -> Procesando: Limpieza y hogar > Utensilios de limpieza y calzado (ID: 244)
# -> Procesando: Maquillaje (ID: 22)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/22/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/22/
# -> Procesando: Maquillaje > Bases de maquillaje y corrector (ID: 206)
# -> Procesando: Maquillaje > Colorete y polvos (ID: 207)
# -> Procesando: Maquillaje > Labios (ID: 208)
# -> Procesando: Maquillaje > Ojos (ID: 210)
# -> Procesando: Maquillaje > Pinceles y brochas (ID: 212)
# -> Procesando: Marisco y pescado (ID: 2)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/2/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/2/
# -> Procesando: Marisco y pescado > Marisco (ID: 32)
# -> Procesando: Marisco y pescado > Pescado congelado (ID: 34)
# -> Procesando: Marisco y pescado > Pescado fresco (ID: 31)
# -> Procesando: Marisco y pescado > Salazones y ahumados (ID: 36)
# -> Procesando: Mascotas (ID: 25)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/25/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/25/
# -> Procesando: Mascotas > Gato (ID: 222)
# -> Procesando: Mascotas > Perro (ID: 221)
# -> Procesando: Mascotas > Otros (ID: 225)
# -> Procesando: Panadería y pastelería (ID: 5)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/5/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/5/
# -> Procesando: Panadería y pastelería > Bollería de horno (ID: 65)
# -> Procesando: Panadería y pastelería > Bollería envasada (ID: 66)
# -> Procesando: Panadería y pastelería > Harina y preparado repostería (ID: 69)
# -> Procesando: Panadería y pastelería > Pan de horno (ID: 59)
# -> Procesando: Panadería y pastelería > Pan de molde y otras especialidades (ID: 60)
# -> Procesando: Panadería y pastelería > Pan tostado y rallado (ID: 62)
# -> Procesando: Panadería y pastelería > Picos, rosquilletas y picatostes (ID: 64)
# -> Procesando: Panadería y pastelería > Tartas y pasteles (ID: 68)
# -> Procesando: Panadería y pastelería > Velas y decoración (ID: 71)
# -> Procesando: Pizzas y platos preparados (ID: 16)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/16/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/16/
# -> Procesando: Pizzas y platos preparados > Listo para Comer (ID: 897)
# -> Procesando: Pizzas y platos preparados > Pizzas (ID: 138)
# -> Procesando: Pizzas y platos preparados > Platos preparados calientes (ID: 140)
# -> Procesando: Pizzas y platos preparados > Platos preparados fríos (ID: 142)
# -> Procesando: Postres y yogures (ID: 11)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/11/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/11/
# -> Procesando: Postres y yogures > Bífidus (ID: 105)
# -> Procesando: Postres y yogures > Flan y natillas (ID: 110)
# -> Procesando: Postres y yogures > Gelatina y otros postres (ID: 111)
# -> Procesando: Postres y yogures > Postres de soja (ID: 106)
# -> Procesando: Postres y yogures > Yogures desnatados (ID: 103)
# -> Procesando: Postres y yogures > Yogures griegos (ID: 109)
# -> Procesando: Postres y yogures > Yogures líquidos (ID: 108)
# -> Procesando: Postres y yogures > Yogures naturales y sabores (ID: 104)
# -> Procesando: Postres y yogures > Yogures y postres infantiles (ID: 107)
# -> Procesando: Zumos (ID: 10)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/10/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/10/
# -> Procesando: Zumos > Fruta variada (ID: 99)
# -> Procesando: Zumos > Melocotón y piña (ID: 100)
# -> Procesando: Zumos > Naranja (ID: 143)
# -> Procesando: Zumos > Tomate y otros sabores (ID: 98)
#
# ✅ Proceso completado. Total de productos únicos guardados: 0

# %%
import requests
import csv
import time

# --- Constantes y Configuración ---
BASE_URL = "https://tienda.mercadona.es/api/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/118.0.0.0 Safari/537.36",
    "Accept": "application/json"
}
CSV_FILE = "productos_mercadona.csv"
PRODUCT_IDS_SEEN = set()  # Para evitar duplicados
FIELDNAMES = [
    "id", 
    "nombre", 
    "subtitulo", 
    "precio_unidad", 
    "precio_ref_valor", 
    "precio_ref_formato",
    "ruta_categoria"
]

# --- Funciones de Utilidad de API ---

def fetch_data(url):
    """Realiza una petición GET a la URL y maneja errores, con delay."""
    try:
        time.sleep(0.5) 
        resp = requests.get(url, headers=HEADERS, timeout=10)
        resp.raise_for_status()
        return resp.json()
    except requests.exceptions.RequestException as e:
        print(f"❌ Error al obtener datos de {url}: {e}")
        return None

# --- Función de Procesamiento y CSV ---

def extract_and_save_product(writer, product, category_path_str):
    """Extrae los campos relevantes del producto y los escribe en el archivo CSV si es nuevo."""
    global PRODUCT_IDS_SEEN
    product_id = product.get('id')
    
    if product_id and product_id not in PRODUCT_IDS_SEEN:
        price_info = product.get('price_instructions', {})
        
        product_data = {
            "id": product_id,
            "nombre": product.get("display_name", "N/A"),
            "subtitulo": product.get("packaging", "N/A"),
            "precio_unidad": price_info.get('unit_price', "N/A"),
            "precio_ref_valor": price_info.get('reference_price', "N/A"),
            "precio_ref_formato": price_info.get('reference_format', "N/A"),
            "ruta_categoria": category_path_str
        }
        
        writer.writerow(product_data)
        PRODUCT_IDS_SEEN.add(product_id)
        # Puedes descomentar la siguiente línea para depuración:
        # print(f"  🛒 Guardado: {product_data['nombre']} | Ruta: {category_path_str}")


def traverse_category(category_info, writer, category_path):
    """
    Recorre recursivamente una categoría y sus subcategorías. 
    Lógica adaptada de PHP: extrae productos anidados Y llama a la siguiente categoría.
    """

    cat_id = category_info.get('id')
    cat_name = category_info.get('name')
    
    if not cat_id or not cat_name:
        return

    # 1. Actualiza la ruta de la categoría actual
    current_category_path = category_path + [cat_name]
    category_path_str = " > ".join(current_category_path)
    
    print(f"-> Procesando: {category_path_str} (ID: {cat_id})")

    # 2. **EXTRAER PRODUCTOS ANIDADOS** (Si la categoría actual ya los trae)
    # Esto ocurre con frecuencia en las respuestas de la API de Mercadona.
    if 'products' in category_info and category_info['products']:
        for product in category_info['products']:
            extract_and_save_product(writer, product, category_path_str)


    # 3. **Obtener el DETALLE COMPLETO DE LA CATEGORÍA** para explorar subniveles
    # La API requiere una segunda llamada para obtener la lista completa de subcategorías
    # o, si es un nivel hoja, para listar todos sus productos.
    category_detail = fetch_data(f"{BASE_URL}categories/{cat_id}/")
    
    if not category_detail:
        return # Salir si la llamada falló

    # 4. **EXTRAER PRODUCTOS DEL DETALLE** (Si es una categoría final/hoja)
    # Si la categoría consultada tiene un listado de productos, también los guardamos.
    if 'products' in category_detail and category_detail['products']:
        for product in category_detail['products']:
            extract_and_save_product(writer, product, category_path_str)
            
    # 5. Llamada recursiva a las subcategorías (categories)
    # Almacenadas en el detalle de la categoría
    if 'categories' in category_detail and category_detail['categories']:
        for sub_cat in category_detail['categories']:
            # Lógica de Backtracking implícita al pasar 'current_category_path'
            traverse_category(sub_cat, writer, current_category_path)


def start_scraping(writer):
    """Inicia el proceso de extracción obteniendo las categorías principales."""
    
    # Obtener categorías de nivel superior
    top_level_data = fetch_data(f"{BASE_URL}categories/")
    
    if not top_level_data or not top_level_data.get('results'):
        print("❌ No se pudieron obtener categorías principales para comenzar.")
        return

    # Iniciar el recorrido por cada categoría principal
    for category in top_level_data['results']:
        traverse_category(category, writer, [])


# --- Ejecución Principal ---

if __name__ == "__main__":
    print(f"Iniciando la extracción de productos de Mercadona y guardando en {CSV_FILE}...")
    
    try:
        # Abrimos el archivo CSV
        with open(CSV_FILE, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=FIELDNAMES, delimiter=';')
            writer.writeheader() 
            
            start_scraping(writer)
            
            print(f"\n✅ Proceso completado. Total de productos únicos guardados: {len(PRODUCT_IDS_SEEN)}")
                
    except Exception as e:
        print(f"\n❌ Ocurrió un error inesperado durante la escritura del archivo: {e}")
# Out:
# Iniciando la extracción de productos de Mercadona y guardando en productos_mercadona.csv...
# -> Procesando: Aceite, especias y salsas (ID: 12)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/12/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/12/
# -> Procesando: Agua y refrescos (ID: 18)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/18/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/18/
# -> Procesando: Aperitivos (ID: 15)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/15/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/15/
# -> Procesando: Arroz, legumbres y pasta (ID: 13)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/13/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/13/
# -> Procesando: Azúcar, caramelos y chocolate (ID: 9)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/9/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/9/
# -> Procesando: Bebé (ID: 24)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/24/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/24/
# -> Procesando: Bodega (ID: 19)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/19/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/19/
# -> Procesando: Cacao, café e infusiones (ID: 8)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/8/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/8/
# -> Procesando: Carne (ID: 3)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/3/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/3/
# -> Procesando: Cereales y galletas (ID: 7)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/7/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/7/
# -> Procesando: Charcutería y quesos (ID: 4)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/4/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/4/
# -> Procesando: Congelados (ID: 17)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/17/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/17/
# -> Procesando: Conservas, caldos y cremas (ID: 14)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/14/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/14/
# -> Procesando: Cuidado del cabello (ID: 21)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/21/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/21/
# -> Procesando: Cuidado facial y corporal (ID: 20)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/20/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/20/
# -> Procesando: Fitoterapia y parafarmacia (ID: 23)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/23/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/23/
# -> Procesando: Fruta y verdura (ID: 1)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/1/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/1/
# -> Procesando: Huevos, leche y mantequilla (ID: 6)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/6/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/6/
# -> Procesando: Limpieza y hogar (ID: 26)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/26/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/26/
# -> Procesando: Maquillaje (ID: 22)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/22/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/22/
# -> Procesando: Marisco y pescado (ID: 2)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/2/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/2/
# -> Procesando: Mascotas (ID: 25)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/25/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/25/
# -> Procesando: Panadería y pastelería (ID: 5)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/5/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/5/
# -> Procesando: Pizzas y platos preparados (ID: 16)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/16/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/16/
# -> Procesando: Postres y yogures (ID: 11)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/11/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/11/
# -> Procesando: Zumos (ID: 10)
# ❌ Error al obtener datos de https://tienda.mercadona.es/api/categories/10/: 404 Client Error: Not Found for url: https://tienda.mercadona.es/api/categories/10/
#
# ✅ Proceso completado. Total de productos únicos guardados: 0
